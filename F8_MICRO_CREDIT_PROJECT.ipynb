# %%
#importing or including important libraries
import pandas as pd
import numpy as np

# %%
#reading the csv file in a data set

ds = pd.read_csv(r'E:\DATA_TRAINED\INTERNSHIP\8_INTERSHIP_PROJECT3\Micro Credit Project\Data file.csv')

#storing the data set in a data frame
df = pd.DataFrame(data=ds)


#displaying the data frame

df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0         220.13    260.13                2.0                0.0  ...
# 1        3691.26   3691.26               20.0                0.0  ...
# 2         900.13    900.13                3.0                0.0  ...
# 3         159.42    159.42               41.0                0.0  ...
# 4        1098.90   1098.90                4.0                0.0  ...
# ...          ...       ...                ...                ...  ...
# 209588   1089.19   1089.19                1.0                0.0  ...
# 209589   1728.36   1728.36                4.0                0.0  ...
# 209590   5861.83   8893.20                3.0                0.0  ...
# 209591    411.83    984.58                2.0               38.0  ...
# 209592    483.92    631.20               13.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0                   6.0                 0.0          2.0            12
# 1                  12.0                 0.0          1.0            12
# 2                   6.0                 0.0          1.0             6
# 3                   6.0                 0.0          2.0            12
# 4                   6.0                 0.0          7.0            42
# ...                 ...                 ...          ...           ...
# 209588              6.0                 0.0          2.0            12
# 209589              6.0                 0.0          3.0            18
# 209590             12.0                 0.0          6.0            54
# 209591             12.0                 0.0          3.0            24
# 209592             12.0                 0.0          2.0            18
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 0                     6                 0.0  29.000000  29.000000      UPW
# 1                    12                 0.0   0.000000   0.000000      UPW
# 2                     6                 0.0   0.000000   0.000000      UPW
# 3                     6                 0.0   0.000000   0.000000      UPW
# 4                     6                 0.0   2.333333   2.333333      UPW
# ...                 ...                 ...        ...        ...      ...
# 209588                6                 0.0   1.000000   1.000000      UPW
# 209589                6                 0.0   1.000000   1.000000      UPW
# 209590               12                 0.0   4.000000   3.833333      UPW
# 209591               12                 0.0   0.000000  10.500000      UPW
# 209592               12                 0.0   0.000000   0.000000      UPW
#
#              pdate
# 0       2016-07-20
# 1       2016-08-10
# 2       2016-08-19
# 3       2016-06-06
# 4       2016-06-22
# ...            ...
# 209588  2016-06-17
# 209589  2016-06-12
# 209590  2016-07-29
# 209591  2016-07-25
# 209592  2016-07-07
#
# [209593 rows x 37 columns]

# %%
pd.set_option('display.max_columns',37)
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 0         220.13    260.13                2.0                0.0
# 1        3691.26   3691.26               20.0                0.0
# 2         900.13    900.13                3.0                0.0
# 3         159.42    159.42               41.0                0.0
# 4        1098.90   1098.90                4.0                0.0
# ...          ...       ...                ...                ...
# 209588   1089.19   1089.19                1.0                0.0
# 209589   1728.36   1728.36                4.0                0.0
# 209590   5861.83   8893.20                3.0                0.0
# 209591    411.83    984.58                2.0               38.0
# 209592    483.92    631.20               13.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 0                   1539              2          21.0             3078.0
# 1                   5787              1           0.0             5787.0
# 2                   1539              1           0.0             1539.0
# 3                    947              0           0.0                0.0
# 4                   2309              7           2.0            20029.0
# ...                  ...            ...           ...                ...
# 209588              4048              3           2.0            10404.0
# 209589               773              4           1.0             3092.0
# 209590              1539              5           8.0             9334.0
# 209591               773              5           4.0            12154.0
# 209592              7526              2           1.0             9065.0
#
#         medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# 0                     1539.0                  7.50              2
# 1                     5787.0                 61.04              1
# 2                     1539.0                 66.32              1
# 3                        0.0                  0.00              1
# 4                     2309.0                 29.00              8
# ...                      ...                   ...            ...
# 209588                3178.0                 91.81              3
# 209589                 773.0                161.30              6
# 209590                1539.0                 51.13             11
# 209591                 773.0                164.00              6
# 209592                4532.5                356.70              3
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0                 21               3078                1539.0
# 1                  0               5787                5787.0
# 2                  0               1539                1539.0
# 3                  0                947                 947.0
# 4                  2              23496                2888.0
# ...              ...                ...                   ...
# 209588             2              10404                3178.0
# 209589             2               4038                 773.0
# 209590             5              18592                1539.0
# 209591             4              17941                2410.5
# 209592            19              16591                7526.0
#
#         medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 0                       7.50            0.0           0.0              0
# 1                      61.04            0.0           0.0              0
# 2                      66.32            0.0           0.0              0
# 3                       2.50            0.0           0.0              0
# 4                      35.00            0.0           0.0              0
# ...                      ...            ...           ...            ...
# 209588                 91.81            0.0           0.0              0
# 209589                111.80            0.0           0.0              0
# 209590                 47.13            0.0           0.0              0
# 209591                100.00            0.0           0.0              1
# 209592                392.20            0.0           0.0              0
#
#         fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0                  0            2            12              6.0
# 1                  0            1            12             12.0
# 2                  0            1             6              6.0
# 3                  0            2            12              6.0
# 4                  0            7            42              6.0
# ...              ...          ...           ...              ...
# 209588             0            2            12              6.0
# 209589             0            3            18              6.0
# 209590             0            4            42             12.0
# 209591             0            2            18             12.0
# 209592             0            2            18             12.0
#
#         medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                      0.0          2.0            12                6
# 1                      0.0          1.0            12               12
# 2                      0.0          1.0             6                6
# 3                      0.0          2.0            12                6
# 4                      0.0          7.0            42                6
# ...                    ...          ...           ...              ...
# 209588                 0.0          2.0            12                6
# 209589                 0.0          3.0            18                6
# 209590                 0.0          6.0            54               12
# 209591                 0.0          3.0            24               12
# 209592                 0.0          2.0            18               12
#
#         medianamnt_loans90  payback30  payback90 pcircle       pdate
# 0                      0.0  29.000000  29.000000     UPW  2016-07-20
# 1                      0.0   0.000000   0.000000     UPW  2016-08-10
# 2                      0.0   0.000000   0.000000     UPW  2016-08-19
# 3                      0.0   0.000000   0.000000     UPW  2016-06-06
# 4                      0.0   2.333333   2.333333     UPW  2016-06-22
# ...                    ...        ...        ...     ...         ...
# 209588                 0.0   1.000000   1.000000     UPW  2016-06-17
# 209589                 0.0   1.000000   1.000000     UPW  2016-06-12
# 209590                 0.0   4.000000   3.833333     UPW  2016-07-29
# 209591                 0.0   0.000000  10.500000     UPW  2016-07-25
# 209592                 0.0   0.000000   0.000000     UPW  2016-07-07
#
# [209593 rows x 37 columns]

# %%
#printing the columns available in data frame
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
#printing the the type of data frame and no. of columns in the dataframe
print(type(df), '\n Number of columns in the dataframe are = ',len(df.columns))
# Out:
# <class 'pandas.core.frame.DataFrame'>
#  Number of columns in the dataframe are =  37

# %%
#displaying the type of data frame columns
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
#displaying the top 5 rows of data frame
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0    220.13    260.13                2.0                0.0              1539
# 1   3691.26   3691.26               20.0                0.0              5787
# 2    900.13    900.13                3.0                0.0              1539
# 3    159.42    159.42               41.0                0.0               947
# 4   1098.90   1098.90                4.0                0.0              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0              2          21.0             3078.0                1539.0
# 1              1           0.0             5787.0                5787.0
# 2              1           0.0             1539.0                1539.0
# 3              0           0.0                0.0                   0.0
# 4              7           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90 pcircle       pdate
# 0                 0.0  29.000000  29.000000     UPW  2016-07-20
# 1                 0.0   0.000000   0.000000     UPW  2016-08-10
# 2                 0.0   0.000000   0.000000     UPW  2016-08-19
# 3                 0.0   0.000000   0.000000     UPW  2016-06-06
# 4                 0.0   2.333333   2.333333     UPW  2016-06-22

# %%
#displaying the bottom 7 rows of data frame
df.tail(7)
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209586      209587      1  60331I70370   254.0  20079.157333  20228.090000
# 209587      209588      1  19900I95200   239.0  14678.000000  14704.900000
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 209586   4003.12   5173.74                2.0                0.0
# 209587  12935.26  16775.60                8.0                0.0
# 209588   1089.19   1089.19                1.0                0.0
# 209589   1728.36   1728.36                4.0                0.0
# 209590   5861.83   8893.20                3.0                0.0
# 209591    411.83    984.58                2.0               38.0
# 209592    483.92    631.20               13.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 209586              1539              9           4.0            17243.0
# 209587              3178              3           3.0            12143.0
# 209588              4048              3           2.0            10404.0
# 209589               773              4           1.0             3092.0
# 209590              1539              5           8.0             9334.0
# 209591               773              5           4.0            12154.0
# 209592              7526              2           1.0             9065.0
#
#         medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# 209586                1547.0                 37.00             17
# 209587                3178.0                914.00              5
# 209588                3178.0                 91.81              3
# 209589                 773.0                161.30              6
# 209590                1539.0                 51.13             11
# 209591                 773.0                164.00              6
# 209592                4532.5                356.70              3
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 209586             2              33719                1547.0
# 209587            17              14455                3178.0
# 209588             2              10404                3178.0
# 209589             2               4038                 773.0
# 209590             5              18592                1539.0
# 209591             4              17941                2410.5
# 209592            19              16591                7526.0
#
#         medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 209586                 37.00            0.0           0.0              0
# 209587                 28.00            0.0           0.0              0
# 209588                 91.81            0.0           0.0              0
# 209589                111.80            0.0           0.0              0
# 209590                 47.13            0.0           0.0              0
# 209591                100.00            0.0           0.0              1
# 209592                392.20            0.0           0.0              0
#
#         fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 209586             0            6            66             12.0
# 209587             0            1            12             12.0
# 209588             0            2            12              6.0
# 209589             0            3            18              6.0
# 209590             0            4            42             12.0
# 209591             0            2            18             12.0
# 209592             0            2            18             12.0
#
#         medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 209586                 0.0         15.0           120               12
# 209587                 1.0          3.0            24               12
# 209588                 0.0          2.0            12                6
# 209589                 0.0          3.0            18                6
# 209590                 0.0          6.0            54               12
# 209591                 0.0          3.0            24               12
# 209592                 0.0          2.0            18               12
#
#         medianamnt_loans90  payback30  payback90 pcircle       pdate
# 209586                 0.0        3.0   2.400000     UPW  2016-07-22
# 209587                 1.0        0.0  30.000000     UPW  2016-08-02
# 209588                 0.0        1.0   1.000000     UPW  2016-06-17
# 209589                 0.0        1.0   1.000000     UPW  2016-06-12
# 209590                 0.0        4.0   3.833333     UPW  2016-07-29
# 209591                 0.0        0.0  10.500000     UPW  2016-07-25
# 209592                 0.0        0.0   0.000000     UPW  2016-07-07

# %%
#displaying 8 sample rows of the data frame it shows different rows in every execution
df.sample(8)
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 54807        54808      1  23271I70787   541.0   7665.955000       7730.73
# 114886      114887      1  27070I90584  1305.0  10915.268333      10963.65
# 205241      205242      1  89447I90587   960.0     32.400000         32.40
# 114633      114634      1  27320I70374   728.0   4188.116667       4255.50
# 145904      145905      1  97391I95201   103.0  12800.000000      14932.80
# 209067      209068      1  39245I89234   424.0     51.680000         51.68
# 46536        46537      1  65098I70374   681.0   3165.264000       3189.14
# 126699      126700      0  06275I88688    99.0      0.000000          0.00
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 54807     446.80    186.05                3.0                0.0
# 114886   1261.82   1767.52                6.0                0.0
# 205241   1249.20   1249.20                2.0                0.0
# 114633    407.36    565.83                3.0                0.0
# 145904   1385.85   2823.10                2.0                0.0
# 209067    878.20    878.20               10.0                0.0
# 46536    6460.82   6900.90                2.0                0.0
# 126699    576.54    576.54                0.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 54807                770              3          19.0             5588.0
# 114886              3178              8           2.0            13387.0
# 205241               773              4           8.0             2492.0
# 114633              1539              3           7.0             8765.0
# 145904               770             12           1.0            10015.0
# 209067              1539              2           6.0             3078.0
# 46536               2309              9           3.0            32954.0
# 126699                 0              0           0.0                0.0
#
#         medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# 54807                  770.0                123.20              5
# 114886                 771.5                 43.50             11
# 205241                 773.0                 29.10              4
# 114633                3178.0                 71.00              4
# 145904                 770.0                 60.50             32
# 209067                1539.0                157.74              2
# 46536                 4048.0                118.00             12
# 126699                   0.0                  0.00              0
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 54807             19              17636                4048.0
# 114886             2              17254                 773.0
# 205241             8               2492                 773.0
# 114633             3              12813                3613.0
# 145904             1              26989                 773.0
# 209067             6               3078                1539.0
# 46536              3              48141                4048.0
# 126699             0                  0                   0.0
#
#         medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 54807                 35.200            0.0           0.0              0
# 114886                56.500            0.0           0.0              0
# 205241                29.100            0.0           0.0              0
# 114633                47.000            0.0           0.0              0
# 145904                56.000            0.0           0.0              0
# 209067               157.740            0.0           0.0              0
# 46536                173.735            0.0           0.0              0
# 126699                 0.000            0.0           0.0              0
#
#         fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 54807              0            3            18              6.0
# 114886             0            2            18             12.0
# 205241             0            3            18              6.0
# 114633             0            2            18             12.0
# 145904             0            1             6              6.0
# 209067             0            1             6              6.0
# 46536              0            9            54              6.0
# 126699             0            1             6              6.0
#
#         medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 54807                  0.0          4.0            24                6
# 114886                 0.0          2.0            18               12
# 205241                 0.0          3.0            18                6
# 114633                 0.0          3.0            24               12
# 145904                 0.0          1.0             6                6
# 209067                 0.0          1.0             6                6
# 46536                  0.0         10.0            60                6
# 126699                 0.0          1.0             6                6
#
#         medianamnt_loans90  payback30  payback90 pcircle       pdate
# 54807                  0.0      3.500   7.333333     UPW  2016-07-25
# 114886                 0.0      0.000   0.000000     UPW  2016-07-13
# 205241                 0.0      8.000   8.000000     UPW  2016-06-18
# 114633                 0.0      0.000   5.500000     UPW  2016-07-13
# 145904                 0.0      0.000   0.000000     UPW  2016-08-03
# 209067                 0.0      0.000   0.000000     UPW  2016-06-20
# 46536                  0.0      1.375   1.333333     UPW  2016-07-02
# 126699                 0.0      0.000   0.000000     UPW  2016-06-03

# %% [markdown]
# # Checking Null Values

# %%
#displaying boolean (T/F) for the values if it is null or not null
df.isnull()
# Out:
#         Unnamed: 0  label  msisdn    aon  daily_decr30  daily_decr90  \
# 0            False  False   False  False         False         False
# 1            False  False   False  False         False         False
# 2            False  False   False  False         False         False
# 3            False  False   False  False         False         False
# 4            False  False   False  False         False         False
# ...            ...    ...     ...    ...           ...           ...
# 209588       False  False   False  False         False         False
# 209589       False  False   False  False         False         False
# 209590       False  False   False  False         False         False
# 209591       False  False   False  False         False         False
# 209592       False  False   False  False         False         False
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 0          False     False              False              False
# 1          False     False              False              False
# 2          False     False              False              False
# 3          False     False              False              False
# 4          False     False              False              False
# ...          ...       ...                ...                ...
# 209588     False     False              False              False
# 209589     False     False              False              False
# 209590     False     False              False              False
# 209591     False     False              False              False
# 209592     False     False              False              False
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 0                  False          False         False              False
# 1                  False          False         False              False
# 2                  False          False         False              False
# 3                  False          False         False              False
# 4                  False          False         False              False
# ...                  ...            ...           ...                ...
# 209588             False          False         False              False
# 209589             False          False         False              False
# 209590             False          False         False              False
# 209591             False          False         False              False
# 209592             False          False         False              False
#
#         medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# 0                      False                 False          False
# 1                      False                 False          False
# 2                      False                 False          False
# 3                      False                 False          False
# 4                      False                 False          False
# ...                      ...                   ...            ...
# 209588                 False                 False          False
# 209589                 False                 False          False
# 209590                 False                 False          False
# 209591                 False                 False          False
# 209592                 False                 False          False
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0              False              False                 False
# 1              False              False                 False
# 2              False              False                 False
# 3              False              False                 False
# 4              False              False                 False
# ...              ...                ...                   ...
# 209588         False              False                 False
# 209589         False              False                 False
# 209590         False              False                 False
# 209591         False              False                 False
# 209592         False              False                 False
#
#         medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 0                      False          False         False          False
# 1                      False          False         False          False
# 2                      False          False         False          False
# 3                      False          False         False          False
# 4                      False          False         False          False
# ...                      ...            ...           ...            ...
# 209588                 False          False         False          False
# 209589                 False          False         False          False
# 209590                 False          False         False          False
# 209591                 False          False         False          False
# 209592                 False          False         False          False
#
#         fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              False        False         False            False
# 1              False        False         False            False
# 2              False        False         False            False
# 3              False        False         False            False
# 4              False        False         False            False
# ...              ...          ...           ...              ...
# 209588         False        False         False            False
# 209589         False        False         False            False
# 209590         False        False         False            False
# 209591         False        False         False            False
# 209592         False        False         False            False
#
#         medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                    False        False         False            False
# 1                    False        False         False            False
# 2                    False        False         False            False
# 3                    False        False         False            False
# 4                    False        False         False            False
# ...                    ...          ...           ...              ...
# 209588               False        False         False            False
# 209589               False        False         False            False
# 209590               False        False         False            False
# 209591               False        False         False            False
# 209592               False        False         False            False
#
#         medianamnt_loans90  payback30  payback90  pcircle  pdate
# 0                    False      False      False    False  False
# 1                    False      False      False    False  False
# 2                    False      False      False    False  False
# 3                    False      False      False    False  False
# 4                    False      False      False    False  False
# ...                    ...        ...        ...      ...    ...
# 209588               False      False      False    False  False
# 209589               False      False      False    False  False
# 209590               False      False      False    False  False
# 209591               False      False      False    False  False
# 209592               False      False      False    False  False
#
# [209593 rows x 37 columns]

# %%
#displaying the total number of Null Values available columnwise
df.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 0              0
# medianamnt_ma_rech90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# medianmarechprebal90    0
# sumamnt_ma_rech90       0
# label                   0
# fr_ma_rech90            0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# pdate                   0
# dtype: int64

# %%
#displaying the total number of Null Values available in the entire data frame
df.isnull().sum().sum()
# Out:
# 0

# %%
#showing unique values of the columns
df['label'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#showing number of unique values of the columns
df['label'].nunique()
# Out:
# 2

# %% [markdown]
# #### Since there are no null values so we move further

# %%
#Filling null values with mean in numeric columns and with mode in string (object) columns
#df_old=df.copy() #Keeping a copy of original dataframe that may be required later 


#df['Cuisines'].fillna(df['Cuisines'].mode(),inplace=True)
#mode = df[df['Cuisines']!=" "]['Cuisines'].mode()[0]
#df['Cuisines'] = df['Cuisines'].replace(" ",mode) 
#df['Cuisines'] = df['Cuisines'].replace("NaN",mode)
#df['Cuisines'] = df['Cuisines'].replace(np.nan,mode)

# %% [markdown]
# ##### Now all null values and special values are treated

# %%
df.dtypes.sort_values()
# Out:
# Unnamed: 0                int64
# maxamnt_loans90           int64
# amnt_loans90              int64
# amnt_loans30              int64
# cnt_loans30               int64
# fr_da_rech90              int64
# cnt_da_rech90             int64
# fr_ma_rech90              int64
# cnt_ma_rech90             int64
# cnt_ma_rech30             int64
# sumamnt_ma_rech90         int64
# label                     int64
# last_rech_amt_ma          int64
# last_rech_date_da       float64
# payback90               float64
# payback30               float64
# medianamnt_loans90      float64
# cnt_loans90             float64
# medianamnt_loans30      float64
# maxamnt_loans30         float64
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# cnt_da_rech30           float64
# medianmarechprebal90    float64
# medianamnt_ma_rech90    float64
# rental90                float64
# last_rech_date_ma       float64
# medianmarechprebal30    float64
# medianamnt_ma_rech30    float64
# sumamnt_ma_rech30       float64
# fr_ma_rech30            float64
# fr_da_rech30            float64
# pcircle                  object
# msisdn                   object
# pdate                    object
# dtype: object

# %% [markdown]
# ##### 3 Features are string and 13 Features are int64 and 21 are float64
#
# - The target variable label is int64
#
# - Conclusion : Encoading for string (objet) feature is required

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
sns.heatmap(df.corr().sort_values(by='label'),annot=True)
plt.show()

# %% [markdown]
# #### Encoding of Data

# %%
#getting the names of columns which are object type and numeric type in two different lists
str_columns = []
num_columns = []
for i in df.columns:
    if(df.dtypes[i]=='O'):
        str_columns.append(i)
    else:
        num_columns.append(i)

#Encode the categorical data in int format to be used by Machine Learning
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for i in str_columns:
    df[i]=le.fit_transform(df[i])


df
# Out:
#         Unnamed: 0  label  msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0   40191   272.0   3055.050000   3065.150000
# 1                2      1  142291   712.0  12122.000000  12124.750000
# 2                3      1   33594   535.0   1398.000000   1398.000000
# 3                4      1  104157   241.0     21.228000     21.228000
# 4                5      1    6910   947.0    150.619333    150.619333
# ...            ...    ...     ...     ...           ...           ...
# 209588      209589      1   42866   404.0    151.872333    151.872333
# 209589      209590      1  178248  1075.0     36.936000     36.936000
# 209590      209591      1   53995  1013.0  11843.111667  11904.350000
# 209591      209592      1  111388  1732.0  12488.228333  12574.370000
# 209592      209593      1  121263  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 0         220.13    260.13                2.0                0.0
# 1        3691.26   3691.26               20.0                0.0
# 2         900.13    900.13                3.0                0.0
# 3         159.42    159.42               41.0                0.0
# 4        1098.90   1098.90                4.0                0.0
# ...          ...       ...                ...                ...
# 209588   1089.19   1089.19                1.0                0.0
# 209589   1728.36   1728.36                4.0                0.0
# 209590   5861.83   8893.20                3.0                0.0
# 209591    411.83    984.58                2.0               38.0
# 209592    483.92    631.20               13.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 0                   1539              2          21.0             3078.0
# 1                   5787              1           0.0             5787.0
# 2                   1539              1           0.0             1539.0
# 3                    947              0           0.0                0.0
# 4                   2309              7           2.0            20029.0
# ...                  ...            ...           ...                ...
# 209588              4048              3           2.0            10404.0
# 209589               773              4           1.0             3092.0
# 209590              1539              5           8.0             9334.0
# 209591               773              5           4.0            12154.0
# 209592              7526              2           1.0             9065.0
#
#         medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# 0                     1539.0                  7.50              2
# 1                     5787.0                 61.04              1
# 2                     1539.0                 66.32              1
# 3                        0.0                  0.00              1
# 4                     2309.0                 29.00              8
# ...                      ...                   ...            ...
# 209588                3178.0                 91.81              3
# 209589                 773.0                161.30              6
# 209590                1539.0                 51.13             11
# 209591                 773.0                164.00              6
# 209592                4532.5                356.70              3
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0                 21               3078                1539.0
# 1                  0               5787                5787.0
# 2                  0               1539                1539.0
# 3                  0                947                 947.0
# 4                  2              23496                2888.0
# ...              ...                ...                   ...
# 209588             2              10404                3178.0
# 209589             2               4038                 773.0
# 209590             5              18592                1539.0
# 209591             4              17941                2410.5
# 209592            19              16591                7526.0
#
#         medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 0                       7.50            0.0           0.0              0
# 1                      61.04            0.0           0.0              0
# 2                      66.32            0.0           0.0              0
# 3                       2.50            0.0           0.0              0
# 4                      35.00            0.0           0.0              0
# ...                      ...            ...           ...            ...
# 209588                 91.81            0.0           0.0              0
# 209589                111.80            0.0           0.0              0
# 209590                 47.13            0.0           0.0              0
# 209591                100.00            0.0           0.0              1
# 209592                392.20            0.0           0.0              0
#
#         fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0                  0            2            12              6.0
# 1                  0            1            12             12.0
# 2                  0            1             6              6.0
# 3                  0            2            12              6.0
# 4                  0            7            42              6.0
# ...              ...          ...           ...              ...
# 209588             0            2            12              6.0
# 209589             0            3            18              6.0
# 209590             0            4            42             12.0
# 209591             0            2            18             12.0
# 209592             0            2            18             12.0
#
#         medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                      0.0          2.0            12                6
# 1                      0.0          1.0            12               12
# 2                      0.0          1.0             6                6
# 3                      0.0          2.0            12                6
# 4                      0.0          7.0            42                6
# ...                    ...          ...           ...              ...
# 209588                 0.0          2.0            12                6
# 209589                 0.0          3.0            18                6
# 209590                 0.0          6.0            54               12
# 209591                 0.0          3.0            24               12
# 209592                 0.0          2.0            18               12
#
#         medianamnt_loans90  payback30  payback90  pcircle  pdate
# 0                      0.0  29.000000  29.000000        0     49
# 1                      0.0   0.000000   0.000000        0     70
# 2                      0.0   0.000000   0.000000        0     79
# 3                      0.0   0.000000   0.000000        0      5
# 4                      0.0   2.333333   2.333333        0     21
# ...                    ...        ...        ...      ...    ...
# 209588                 0.0   1.000000   1.000000        0     16
# 209589                 0.0   1.000000   1.000000        0     11
# 209590                 0.0   4.000000   3.833333        0     58
# 209591                 0.0   0.000000  10.500000        0     54
# 209592                 0.0   0.000000   0.000000        0     36
#
# [209593 rows x 37 columns]

# %%
#showing old string columns
df[str_columns]
# Out:
#         msisdn  pcircle  pdate
# 0        40191        0     49
# 1       142291        0     70
# 2        33594        0     79
# 3       104157        0      5
# 4         6910        0     21
# ...        ...      ...    ...
# 209588   42866        0     16
# 209589  178248        0     11
# 209590   53995        0     58
# 209591  111388        0     54
# 209592  121263        0     36
#
# [209593 rows x 3 columns]

# %%
#showing data types of all columns
df.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                    int32
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# medianamnt_loans90      float64
# payback30               float64
# payback90               float64
# pcircle                   int32
# pdate                     int32
# dtype: object

# %% [markdown]
# - All columns are converted in numeric type

# %% [markdown]
# - 9551 rows × 22 columns are in the data frame

# %%
#Checking null values by showing it on heatmap, There is no null values in dataframe now
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# ##### There are no null values in the data frame

# %%
#Showing other categorical columns unique values and their counts 
for i in str_columns:
    print("Unique values in feature ",i," are = ",df[i].unique()," and their count is =", df[i].nunique(),"\n")
# Out:
# Unique values in feature  msisdn  are =  [ 40191 142291  33594 ...  42866 111388 121263]  and their count is = 186243
#
# Unique values in feature  pcircle  are =  [0]  and their count is = 1
#
# Unique values in feature  pdate  are =  [49 70 79  5 21 31 34 65 14  7 11 19 28 15 63 23 33 32 30 68 25 22 35 38
#   9  6 26 71 29 18 55 74 13 20 24 27 10 56 52 76 75  1  4 62 57 47 78 45
#  58 50  2 12 61 42 39  8 44 40 69 72 51  3 53 17 73 16 67 41 66 48 81 64
#  54 59 77 37 43  0 36 46 60 80]  and their count is = 82

# %% [markdown]
# My target variable Price Range has 4 unique classes  and those are from 1,2,3,4

# %% [markdown]
# # EDA
# Visualization of Data

# %%
#importing seaborn library as sns
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Showing counts of target feature
sns.countplot(x=df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# - There is a class imbalance that need to be treeted

# %%
#showing frequency of primary_fuel column
sns.displot(x=df['label'],kde=True)
df['label'].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# ##### Multipolar distribution

# %%
#showing distribution of categorical columns using displot
for i in str_columns:
    sns.displot(x=df[i],kde=True)
    df[i].value_counts()

# %%
#showing distribution of numerica columns using displot
#a for i in num_columns:
 #   sns.displot(x=df[i],kde=True)
  #  df[i].value_counts()

# %% [markdown]
# - Above displots shows the distribution of many columns are not normally distributed / gausian distribution

# %%
#showing correlation of target(classification) feature with all other features 
df.corr()['label'].sort_values()
# Out:
# fr_da_rech90           -0.005418
# medianmarechprebal30   -0.004829
# aon                    -0.003785
# fr_da_rech30           -0.000027
# maxamnt_loans30         0.000248
# Unnamed: 0              0.000403
# fr_ma_rech30            0.001330
# last_rech_date_da       0.001711
# msisdn                  0.001976
# cnt_da_rech90           0.002999
# last_rech_date_ma       0.003728
# cnt_da_rech30           0.003827
# cnt_loans90             0.004733
# medianamnt_loans90      0.035747
# medianmarechprebal90    0.039300
# medianamnt_loans30      0.044589
# payback30               0.048336
# payback90               0.049183
# rental30                0.058085
# rental90                0.075521
# maxamnt_loans90         0.084144
# fr_ma_rech90            0.084385
# medianamnt_ma_rech90    0.120855
# last_rech_amt_ma        0.131804
# medianamnt_ma_rech30    0.141490
# pdate                   0.162687
# daily_decr90            0.166150
# daily_decr30            0.168298
# cnt_loans30             0.196283
# amnt_loans30            0.197272
# amnt_loans90            0.199788
# sumamnt_ma_rech30       0.202828
# sumamnt_ma_rech90       0.205793
# cnt_ma_rech90           0.236392
# cnt_ma_rech30           0.237331
# label                   1.000000
# pcircle                      NaN
# Name: label, dtype: float64

# %%
#showing correlation with the help of heatmap
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ##### following features have nearly 0 correlation with both the target features so we will drop these
#
# fr_da_rech90
#
# medianmarechprebal30
#
# aon
#
# fr_da_rech30
#
# maxamnt_loans30
#
# Unnamed: 0
#
# fr_ma_rech30
#
# last_rech_date_da
#
# msisdn
#
# cnt_da_rech90
#
# last_rech_date_ma
#
# cnt_da_rech30
#
# cnt_loans90

# %%
#declaring a list of columns names to be deleted
delc=['fr_da_rech90','medianmarechprebal30','aon','fr_da_rech30','maxamnt_loans30','Unnamed: 0','fr_ma_rech30','last_rech_date_da','cnt_da_rech90','last_rech_date_ma','cnt_da_rech30','cnt_loans90']

#droping the columns listed in the above list
df.drop(labels=delc,axis=1,inplace=True)

df.drop(labels='msisdn',axis=1,inplace=True)

#removing columnnames from the num_columns
for i in delc:
    num_columns.remove(i)

str_columns.remove('msisdn')

#showing updated dataframe after dropping features
df
# Out:
#         label  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   3055.050000   3065.150000    220.13    260.13
# 1           1  12122.000000  12124.750000   3691.26   3691.26
# 2           1   1398.000000   1398.000000    900.13    900.13
# 3           1     21.228000     21.228000    159.42    159.42
# 4           1    150.619333    150.619333   1098.90   1098.90
# ...       ...           ...           ...       ...       ...
# 209588      1    151.872333    151.872333   1089.19   1089.19
# 209589      1     36.936000     36.936000   1728.36   1728.36
# 209590      1  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  12488.228333  12574.370000    411.83    984.58
# 209592      1   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_amt_ma  cnt_ma_rech30  sumamnt_ma_rech30  \
# 0                   1539              2             3078.0
# 1                   5787              1             5787.0
# 2                   1539              1             1539.0
# 3                    947              0                0.0
# 4                   2309              7            20029.0
# ...                  ...            ...                ...
# 209588              4048              3            10404.0
# 209589               773              4             3092.0
# 209590              1539              5             9334.0
# 209591               773              5            12154.0
# 209592              7526              2             9065.0
#
#         medianamnt_ma_rech30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                     1539.0              2            21               3078
# 1                     5787.0              1             0               5787
# 2                     1539.0              1             0               1539
# 3                        0.0              1             0                947
# 4                     2309.0              8             2              23496
# ...                      ...            ...           ...                ...
# 209588                3178.0              3             2              10404
# 209589                 773.0              6             2               4038
# 209590                1539.0             11             5              18592
# 209591                 773.0              6             4              17941
# 209592                4532.5              3            19              16591
#
#         medianamnt_ma_rech90  medianmarechprebal90  cnt_loans30  amnt_loans30  \
# 0                     1539.0                  7.50            2            12
# 1                     5787.0                 61.04            1            12
# 2                     1539.0                 66.32            1             6
# 3                      947.0                  2.50            2            12
# 4                     2888.0                 35.00            7            42
# ...                      ...                   ...          ...           ...
# 209588                3178.0                 91.81            2            12
# 209589                 773.0                111.80            3            18
# 209590                1539.0                 47.13            4            42
# 209591                2410.5                100.00            2            18
# 209592                7526.0                392.20            2            18
#
#         medianamnt_loans30  amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# 0                      0.0            12                6                 0.0
# 1                      0.0            12               12                 0.0
# 2                      0.0             6                6                 0.0
# 3                      0.0            12                6                 0.0
# 4                      0.0            42                6                 0.0
# ...                    ...           ...              ...                 ...
# 209588                 0.0            12                6                 0.0
# 209589                 0.0            18                6                 0.0
# 209590                 0.0            54               12                 0.0
# 209591                 0.0            24               12                 0.0
# 209592                 0.0            18               12                 0.0
#
#         payback30  payback90  pcircle  pdate
# 0       29.000000  29.000000        0     49
# 1        0.000000   0.000000        0     70
# 2        0.000000   0.000000        0     79
# 3        0.000000   0.000000        0      5
# 4        2.333333   2.333333        0     21
# ...           ...        ...      ...    ...
# 209588   1.000000   1.000000        0     16
# 209589   1.000000   1.000000        0     11
# 209590   4.000000   3.833333        0     58
# 209591   0.000000  10.500000        0     54
# 209592   0.000000   0.000000        0     36
#
# [209593 rows x 24 columns]

# %%
#showing information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   daily_decr30          209593 non-null  float64
#  2   daily_decr90          209593 non-null  float64
#  3   rental30              209593 non-null  float64
#  4   rental90              209593 non-null  float64
#  5   last_rech_amt_ma      209593 non-null  int64
#  6   cnt_ma_rech30         209593 non-null  int64
#  7   sumamnt_ma_rech30     209593 non-null  float64
#  8   medianamnt_ma_rech30  209593 non-null  float64
#  9   cnt_ma_rech90         209593 non-null  int64
#  10  fr_ma_rech90          209593 non-null  int64
#  11  sumamnt_ma_rech90     209593 non-null  int64
#  12  medianamnt_ma_rech90  209593 non-null  float64
#  13  medianmarechprebal90  209593 non-null  float64
#  14  cnt_loans30           209593 non-null  int64
#  15  amnt_loans30          209593 non-null  int64
#  16  medianamnt_loans30    209593 non-null  float64
#  17  amnt_loans90          209593 non-null  int64
#  18  maxamnt_loans90       209593 non-null  int64
#  19  medianamnt_loans90    209593 non-null  float64
#  20  payback30             209593 non-null  float64
#  21  payback90             209593 non-null  float64
#  22  pcircle               209593 non-null  int32
#  23  pdate                 209593 non-null  int32
# dtypes: float64(12), int32(2), int64(10)
# memory usage: 36.8 MB

# %% [markdown]
# #### Less correlated columns are deleted

# %%
#showing correlation using heatmap after deleting some not important features
plt.figure(figsize=(30,20))
sns.heatmap(df.corr().sort_values(by='label'),annot=True,annot_kws={'fontsize': 15})
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

#showing the presence of values of Price range with respect to City feature
df.plot(kind = 'scatter', x = 'label', y = 'cnt_ma_rech30')
# Out:
# <AxesSubplot:xlabel='label', ylabel='cnt_ma_rech30'>

# %% [markdown]
# #### 1 has higher data points

# %%
#Creating dataframe of string columns and numeric columns
df_str=df.drop(columns=num_columns,axis=1)
df_num=df.drop(columns=str_columns,axis=1)

# %%
df_str
# Out:
#         pcircle  pdate
# 0             0     49
# 1             0     70
# 2             0     79
# 3             0      5
# 4             0     21
# ...         ...    ...
# 209588        0     16
# 209589        0     11
# 209590        0     58
# 209591        0     54
# 209592        0     36
#
# [209593 rows x 2 columns]

# %%
df_num
# Out:
#         label  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   3055.050000   3065.150000    220.13    260.13
# 1           1  12122.000000  12124.750000   3691.26   3691.26
# 2           1   1398.000000   1398.000000    900.13    900.13
# 3           1     21.228000     21.228000    159.42    159.42
# 4           1    150.619333    150.619333   1098.90   1098.90
# ...       ...           ...           ...       ...       ...
# 209588      1    151.872333    151.872333   1089.19   1089.19
# 209589      1     36.936000     36.936000   1728.36   1728.36
# 209590      1  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  12488.228333  12574.370000    411.83    984.58
# 209592      1   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_amt_ma  cnt_ma_rech30  sumamnt_ma_rech30  \
# 0                   1539              2             3078.0
# 1                   5787              1             5787.0
# 2                   1539              1             1539.0
# 3                    947              0                0.0
# 4                   2309              7            20029.0
# ...                  ...            ...                ...
# 209588              4048              3            10404.0
# 209589               773              4             3092.0
# 209590              1539              5             9334.0
# 209591               773              5            12154.0
# 209592              7526              2             9065.0
#
#         medianamnt_ma_rech30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                     1539.0              2            21               3078
# 1                     5787.0              1             0               5787
# 2                     1539.0              1             0               1539
# 3                        0.0              1             0                947
# 4                     2309.0              8             2              23496
# ...                      ...            ...           ...                ...
# 209588                3178.0              3             2              10404
# 209589                 773.0              6             2               4038
# 209590                1539.0             11             5              18592
# 209591                 773.0              6             4              17941
# 209592                4532.5              3            19              16591
#
#         medianamnt_ma_rech90  medianmarechprebal90  cnt_loans30  amnt_loans30  \
# 0                     1539.0                  7.50            2            12
# 1                     5787.0                 61.04            1            12
# 2                     1539.0                 66.32            1             6
# 3                      947.0                  2.50            2            12
# 4                     2888.0                 35.00            7            42
# ...                      ...                   ...          ...           ...
# 209588                3178.0                 91.81            2            12
# 209589                 773.0                111.80            3            18
# 209590                1539.0                 47.13            4            42
# 209591                2410.5                100.00            2            18
# 209592                7526.0                392.20            2            18
#
#         medianamnt_loans30  amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# 0                      0.0            12                6                 0.0
# 1                      0.0            12               12                 0.0
# 2                      0.0             6                6                 0.0
# 3                      0.0            12                6                 0.0
# 4                      0.0            42                6                 0.0
# ...                    ...           ...              ...                 ...
# 209588                 0.0            12                6                 0.0
# 209589                 0.0            18                6                 0.0
# 209590                 0.0            54               12                 0.0
# 209591                 0.0            24               12                 0.0
# 209592                 0.0            18               12                 0.0
#
#         payback30  payback90
# 0       29.000000  29.000000
# 1        0.000000   0.000000
# 2        0.000000   0.000000
# 3        0.000000   0.000000
# 4        2.333333   2.333333
# ...           ...        ...
# 209588   1.000000   1.000000
# 209589   1.000000   1.000000
# 209590   4.000000   3.833333
# 209591   0.000000  10.500000
# 209592   0.000000   0.000000
#
# [209593 rows x 22 columns]

# %%
#Showing the distribution of numeric features
#df_num.plot(kind='kde',subplots=True, layout=(5,6), sharex=False, legend=False, fontsize=1, figsize=(20,16),title=list(df_num.columns))

#plt.show()

# %% [markdown]
# ##### Some features are skewed and many features are in normal  distribution

# %%
#showing the pairplot for all the features in the data frame
#sns.pairplot(data=df)

# %%
#showing box plots
df_num.plot(kind='box', subplots=True, layout=(6,5), sharex=False, legend=False, fontsize=1, figsize=(20,16),title=list(df_num.columns))
plt.show()

# %% [markdown]
# - almost all features shows outliers

# %% [markdown]
# #### Describe the Dataset

# %%
#Describing the data and showing it in transpose manner
df_num.describe().T
# Out:
#                          count          mean           std           min  \
# label                 209593.0      0.875177      0.330519      0.000000
# daily_decr30          209593.0   5381.402289   9220.623400    -93.012667
# daily_decr90          209593.0   6082.515068  10918.812767    -93.012667
# rental30              209593.0   2692.581910   4308.586781 -23737.140000
# rental90              209593.0   3483.406534   5770.461279 -24720.580000
# last_rech_amt_ma      209593.0   2064.452797   2370.786034      0.000000
# cnt_ma_rech30         209593.0      3.978057      4.256090      0.000000
# sumamnt_ma_rech30     209593.0   7704.501157  10139.621714      0.000000
# medianamnt_ma_rech30  209593.0   1812.817952   2070.864620      0.000000
# cnt_ma_rech90         209593.0      6.315430      7.193470      0.000000
# fr_ma_rech90          209593.0      7.716780     12.590251      0.000000
# sumamnt_ma_rech90     209593.0  12396.218352  16857.793882      0.000000
# medianamnt_ma_rech90  209593.0   1864.595821   2081.680664      0.000000
# medianmarechprebal90  209593.0     92.025541    369.215658   -200.000000
# cnt_loans30           209593.0      2.758981      2.554502      0.000000
# amnt_loans30          209593.0     17.952021     17.379741      0.000000
# medianamnt_loans30    209593.0      0.054029      0.218039      0.000000
# amnt_loans90          209593.0     23.645398     26.469861      0.000000
# maxamnt_loans90       209593.0      6.703134      2.103864      0.000000
# medianamnt_loans90    209593.0      0.046077      0.200692      0.000000
# payback30             209593.0      3.398826      8.813729      0.000000
# payback90             209593.0      4.321485     10.308108      0.000000
#
#                            25%          50%       75%        max
# label                    1.000     1.000000      1.00       1.00
# daily_decr30            42.440  1469.175667   7244.00  265926.00
# daily_decr90            42.692  1500.000000   7802.79  320630.00
# rental30               280.420  1083.570000   3356.94  198926.11
# rental90               300.260  1334.000000   4201.79  200148.11
# last_rech_amt_ma       770.000  1539.000000   2309.00   55000.00
# cnt_ma_rech30            1.000     3.000000      5.00     203.00
# sumamnt_ma_rech30     1540.000  4628.000000  10010.00  810096.00
# medianamnt_ma_rech30   770.000  1539.000000   1924.00   55000.00
# cnt_ma_rech90            2.000     4.000000      8.00     336.00
# fr_ma_rech90             0.000     2.000000      8.00      88.00
# sumamnt_ma_rech90     2317.000  7226.000000  16000.00  953036.00
# medianamnt_ma_rech90   773.000  1539.000000   1924.00   55000.00
# medianmarechprebal90    14.600    36.000000     79.31   41456.50
# cnt_loans30              1.000     2.000000      4.00      50.00
# amnt_loans30             6.000    12.000000     24.00     306.00
# medianamnt_loans30       0.000     0.000000      0.00       3.00
# amnt_loans90             6.000    12.000000     30.00     438.00
# maxamnt_loans90          6.000     6.000000      6.00      12.00
# medianamnt_loans90       0.000     0.000000      0.00       3.00
# payback30                0.000     0.000000      3.75     171.50
# payback90                0.000     1.666667      4.50     171.50

# %%
#showing important columns of the describe 
df_desc=df_num.describe().T
df_desc=pd.DataFrame(df_desc,columns=['mean','50%'])
df_desc.rename(columns={'mean': 'MEAN','50%':'MEDIAN'},inplace=True)  
df_desc
# Out:
#                               MEAN       MEDIAN
# label                     0.875177     1.000000
# daily_decr30           5381.402289  1469.175667
# daily_decr90           6082.515068  1500.000000
# rental30               2692.581910  1083.570000
# rental90               3483.406534  1334.000000
# last_rech_amt_ma       2064.452797  1539.000000
# cnt_ma_rech30             3.978057     3.000000
# sumamnt_ma_rech30      7704.501157  4628.000000
# medianamnt_ma_rech30   1812.817952  1539.000000
# cnt_ma_rech90             6.315430     4.000000
# fr_ma_rech90              7.716780     2.000000
# sumamnt_ma_rech90     12396.218352  7226.000000
# medianamnt_ma_rech90   1864.595821  1539.000000
# medianmarechprebal90     92.025541    36.000000
# cnt_loans30               2.758981     2.000000
# amnt_loans30             17.952021    12.000000
# medianamnt_loans30        0.054029     0.000000
# amnt_loans90             23.645398    12.000000
# maxamnt_loans90           6.703134     6.000000
# medianamnt_loans90        0.046077     0.000000
# payback30                 3.398826     0.000000
# payback90                 4.321485     1.666667

# %% [markdown]
# ##### The Mean and median of the columns are as above

# %%
#showing the describe values in heatmap
import matplotlib.pyplot as plt
plt.figure(figsize=(22, 7))
sns.heatmap(df.describe().T,annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Checking Outliers

# %% [markdown]
# Outliers present as per box plot , plotted above

# %%
#Declaring variables 
collist=df_num.columns.values
ncol=20
nrow=10

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data=df_num[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# Outliers are present in almost all the features of the dataset

# %% [markdown]
# #### Checking outliers with zscore and removing these

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
np.where(z>3)
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64),
#  array([10, 10, 21, ..., 17, 16, 19], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
# Empty DataFrame
# Columns: [label, daily_decr30, daily_decr90, rental30, rental90, last_rech_amt_ma, cnt_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_loans30, amnt_loans30, medianamnt_loans30, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, pcircle, pdate]
# Index: []

# %%
df_new_z.shape
# Out:
# (0, 24)

# %%
df.shape
# Out:
# (209593, 24)

# %%
data_loss=(209593-0)/209593*100
data_loss
# Out:
# 100.0

# %% [markdown]
# ##### Data loss is 100% and we can not afford it so we will not remove outliers

# %%
#using the previous dataframe
df
# Out:
#         label  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   3055.050000   3065.150000    220.13    260.13
# 1           1  12122.000000  12124.750000   3691.26   3691.26
# 2           1   1398.000000   1398.000000    900.13    900.13
# 3           1     21.228000     21.228000    159.42    159.42
# 4           1    150.619333    150.619333   1098.90   1098.90
# ...       ...           ...           ...       ...       ...
# 209588      1    151.872333    151.872333   1089.19   1089.19
# 209589      1     36.936000     36.936000   1728.36   1728.36
# 209590      1  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  12488.228333  12574.370000    411.83    984.58
# 209592      1   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_amt_ma  cnt_ma_rech30  sumamnt_ma_rech30  \
# 0                   1539              2             3078.0
# 1                   5787              1             5787.0
# 2                   1539              1             1539.0
# 3                    947              0                0.0
# 4                   2309              7            20029.0
# ...                  ...            ...                ...
# 209588              4048              3            10404.0
# 209589               773              4             3092.0
# 209590              1539              5             9334.0
# 209591               773              5            12154.0
# 209592              7526              2             9065.0
#
#         medianamnt_ma_rech30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                     1539.0              2            21               3078
# 1                     5787.0              1             0               5787
# 2                     1539.0              1             0               1539
# 3                        0.0              1             0                947
# 4                     2309.0              8             2              23496
# ...                      ...            ...           ...                ...
# 209588                3178.0              3             2              10404
# 209589                 773.0              6             2               4038
# 209590                1539.0             11             5              18592
# 209591                 773.0              6             4              17941
# 209592                4532.5              3            19              16591
#
#         medianamnt_ma_rech90  medianmarechprebal90  cnt_loans30  amnt_loans30  \
# 0                     1539.0                  7.50            2            12
# 1                     5787.0                 61.04            1            12
# 2                     1539.0                 66.32            1             6
# 3                      947.0                  2.50            2            12
# 4                     2888.0                 35.00            7            42
# ...                      ...                   ...          ...           ...
# 209588                3178.0                 91.81            2            12
# 209589                 773.0                111.80            3            18
# 209590                1539.0                 47.13            4            42
# 209591                2410.5                100.00            2            18
# 209592                7526.0                392.20            2            18
#
#         medianamnt_loans30  amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# 0                      0.0            12                6                 0.0
# 1                      0.0            12               12                 0.0
# 2                      0.0             6                6                 0.0
# 3                      0.0            12                6                 0.0
# 4                      0.0            42                6                 0.0
# ...                    ...           ...              ...                 ...
# 209588                 0.0            12                6                 0.0
# 209589                 0.0            18                6                 0.0
# 209590                 0.0            54               12                 0.0
# 209591                 0.0            24               12                 0.0
# 209592                 0.0            18               12                 0.0
#
#         payback30  payback90  pcircle  pdate
# 0       29.000000  29.000000        0     49
# 1        0.000000   0.000000        0     70
# 2        0.000000   0.000000        0     79
# 3        0.000000   0.000000        0      5
# 4        2.333333   2.333333        0     21
# ...           ...        ...      ...    ...
# 209588   1.000000   1.000000        0     16
# 209589   1.000000   1.000000        0     11
# 209590   4.000000   3.833333        0     58
# 209591   0.000000  10.500000        0     54
# 209592   0.000000   0.000000        0     36
#
# [209593 rows x 24 columns]

# %% [markdown]
# ### Separating the data into feature and target

# %%
x=df.drop('label', axis=1)
y=df['label']

# %%
x
# Out:
#         daily_decr30  daily_decr90  rental30  rental90  last_rech_amt_ma  \
# 0        3055.050000   3065.150000    220.13    260.13              1539
# 1       12122.000000  12124.750000   3691.26   3691.26              5787
# 2        1398.000000   1398.000000    900.13    900.13              1539
# 3          21.228000     21.228000    159.42    159.42               947
# 4         150.619333    150.619333   1098.90   1098.90              2309
# ...              ...           ...       ...       ...               ...
# 209588    151.872333    151.872333   1089.19   1089.19              4048
# 209589     36.936000     36.936000   1728.36   1728.36               773
# 209590  11843.111667  11904.350000   5861.83   8893.20              1539
# 209591  12488.228333  12574.370000    411.83    984.58               773
# 209592   4489.362000   4534.820000    483.92    631.20              7526
#
#         cnt_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  cnt_ma_rech90  \
# 0                   2             3078.0                1539.0              2
# 1                   1             5787.0                5787.0              1
# 2                   1             1539.0                1539.0              1
# 3                   0                0.0                   0.0              1
# 4                   7            20029.0                2309.0              8
# ...               ...                ...                   ...            ...
# 209588              3            10404.0                3178.0              3
# 209589              4             3092.0                 773.0              6
# 209590              5             9334.0                1539.0             11
# 209591              5            12154.0                 773.0              6
# 209592              2             9065.0                4532.5              3
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0                 21               3078                1539.0
# 1                  0               5787                5787.0
# 2                  0               1539                1539.0
# 3                  0                947                 947.0
# 4                  2              23496                2888.0
# ...              ...                ...                   ...
# 209588             2              10404                3178.0
# 209589             2               4038                 773.0
# 209590             5              18592                1539.0
# 209591             4              17941                2410.5
# 209592            19              16591                7526.0
#
#         medianmarechprebal90  cnt_loans30  amnt_loans30  medianamnt_loans30  \
# 0                       7.50            2            12                 0.0
# 1                      61.04            1            12                 0.0
# 2                      66.32            1             6                 0.0
# 3                       2.50            2            12                 0.0
# 4                      35.00            7            42                 0.0
# ...                      ...          ...           ...                 ...
# 209588                 91.81            2            12                 0.0
# 209589                111.80            3            18                 0.0
# 209590                 47.13            4            42                 0.0
# 209591                100.00            2            18                 0.0
# 209592                392.20            2            18                 0.0
#
#         amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 0                 12                6                 0.0  29.000000
# 1                 12               12                 0.0   0.000000
# 2                  6                6                 0.0   0.000000
# 3                 12                6                 0.0   0.000000
# 4                 42                6                 0.0   2.333333
# ...              ...              ...                 ...        ...
# 209588            12                6                 0.0   1.000000
# 209589            18                6                 0.0   1.000000
# 209590            54               12                 0.0   4.000000
# 209591            24               12                 0.0   0.000000
# 209592            18               12                 0.0   0.000000
#
#         payback90  pcircle  pdate
# 0       29.000000        0     49
# 1        0.000000        0     70
# 2        0.000000        0     79
# 3        0.000000        0      5
# 4        2.333333        0     21
# ...           ...      ...    ...
# 209588   1.000000        0     16
# 209589   1.000000        0     11
# 209590   3.833333        0     58
# 209591  10.500000        0     54
# 209592   0.000000        0     36
#
# [209593 rows x 23 columns]

# %%
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 209593, dtype: int64

# %% [markdown]
# #### Checking Variance Influence Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(x):
    vif=pd.DataFrame()
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
    vif['Features']=x.columns
    print(vif)

# %%
calc_vif(x)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1717: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss
#     VIF FACTOR              Features
# 0    39.364256          daily_decr30
# 1    41.886787          daily_decr90
# 2    18.318142              rental30
# 3    19.173983              rental90
# 4     6.028741      last_rech_amt_ma
# 5    28.117526         cnt_ma_rech30
# 6    20.118494     sumamnt_ma_rech30
# 7     8.960365  medianamnt_ma_rech30
# 8    29.105300         cnt_ma_rech90
# 9     1.442107          fr_ma_rech90
# 10   23.352138     sumamnt_ma_rech90
# 11   10.111630  medianamnt_ma_rech90
# 12    1.131251  medianmarechprebal90
# 13   36.169364           cnt_loans30
# 14   48.566743          amnt_loans30
# 15    6.390361    medianamnt_loans30
# 16   19.540195          amnt_loans90
# 17    7.165131       maxamnt_loans90
# 18    6.325210    medianamnt_loans90
# 19    3.760530             payback30
# 20    3.939856             payback90
# 21         NaN               pcircle
# 22    6.548789                 pdate

# %% [markdown]
# #### colinearity is in acceptable range

# %%
x=pd.DataFrame(x)

# %% [markdown]
# - vif is less than 50 or near and no similar values so we leave the process of treating colinearity

# %% [markdown]
# ##### Transforming data

# %%
#showing skewness of features in sorted order
x.skew().sort_values()
# Out:
# pcircle                  0.000000
# pdate                    0.116409
# maxamnt_loans90          1.678304
# fr_ma_rech90             2.285423
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# amnt_loans90             3.150006
# cnt_ma_rech30            3.283842
# cnt_ma_rech90            3.425254
# medianamnt_ma_rech30     3.512324
# medianamnt_ma_rech90     3.752706
# last_rech_amt_ma         3.781149
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental90                 4.437681
# rental30                 4.521929
# medianamnt_loans30       4.551043
# medianamnt_loans90       4.895720
# sumamnt_ma_rech90        4.897950
# sumamnt_ma_rech30        6.386787
# payback90                6.899951
# payback30                8.310695
# medianmarechprebal90    44.880503
# dtype: float64

# %% [markdown]
# - skewness is present in few features so we will remove it

# %%
#making a new dataframe of feature variables
x1=pd.DataFrame(data=x,columns=x.columns)
x1
# Out:
#         daily_decr30  daily_decr90  rental30  rental90  last_rech_amt_ma  \
# 0        3055.050000   3065.150000    220.13    260.13              1539
# 1       12122.000000  12124.750000   3691.26   3691.26              5787
# 2        1398.000000   1398.000000    900.13    900.13              1539
# 3          21.228000     21.228000    159.42    159.42               947
# 4         150.619333    150.619333   1098.90   1098.90              2309
# ...              ...           ...       ...       ...               ...
# 209588    151.872333    151.872333   1089.19   1089.19              4048
# 209589     36.936000     36.936000   1728.36   1728.36               773
# 209590  11843.111667  11904.350000   5861.83   8893.20              1539
# 209591  12488.228333  12574.370000    411.83    984.58               773
# 209592   4489.362000   4534.820000    483.92    631.20              7526
#
#         cnt_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  cnt_ma_rech90  \
# 0                   2             3078.0                1539.0              2
# 1                   1             5787.0                5787.0              1
# 2                   1             1539.0                1539.0              1
# 3                   0                0.0                   0.0              1
# 4                   7            20029.0                2309.0              8
# ...               ...                ...                   ...            ...
# 209588              3            10404.0                3178.0              3
# 209589              4             3092.0                 773.0              6
# 209590              5             9334.0                1539.0             11
# 209591              5            12154.0                 773.0              6
# 209592              2             9065.0                4532.5              3
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0                 21               3078                1539.0
# 1                  0               5787                5787.0
# 2                  0               1539                1539.0
# 3                  0                947                 947.0
# 4                  2              23496                2888.0
# ...              ...                ...                   ...
# 209588             2              10404                3178.0
# 209589             2               4038                 773.0
# 209590             5              18592                1539.0
# 209591             4              17941                2410.5
# 209592            19              16591                7526.0
#
#         medianmarechprebal90  cnt_loans30  amnt_loans30  medianamnt_loans30  \
# 0                       7.50            2            12                 0.0
# 1                      61.04            1            12                 0.0
# 2                      66.32            1             6                 0.0
# 3                       2.50            2            12                 0.0
# 4                      35.00            7            42                 0.0
# ...                      ...          ...           ...                 ...
# 209588                 91.81            2            12                 0.0
# 209589                111.80            3            18                 0.0
# 209590                 47.13            4            42                 0.0
# 209591                100.00            2            18                 0.0
# 209592                392.20            2            18                 0.0
#
#         amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 0                 12                6                 0.0  29.000000
# 1                 12               12                 0.0   0.000000
# 2                  6                6                 0.0   0.000000
# 3                 12                6                 0.0   0.000000
# 4                 42                6                 0.0   2.333333
# ...              ...              ...                 ...        ...
# 209588            12                6                 0.0   1.000000
# 209589            18                6                 0.0   1.000000
# 209590            54               12                 0.0   4.000000
# 209591            24               12                 0.0   0.000000
# 209592            18               12                 0.0   0.000000
#
#         payback90  pcircle  pdate
# 0       29.000000        0     49
# 1        0.000000        0     70
# 2        0.000000        0     79
# 3        0.000000        0      5
# 4        2.333333        0     21
# ...           ...      ...    ...
# 209588   1.000000        0     16
# 209589   1.000000        0     11
# 209590   3.833333        0     58
# 209591  10.500000        0     54
# 209592   0.000000        0     36
#
# [209593 rows x 23 columns]

# %% [markdown]
# #### Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.naive_bayes import MultinomialNB 
mnb=MultinomialNB()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

from sklearn.preprocessing import power_transform,PowerTransformer

# %% [markdown]
# #### Removing skewness

# %%
x1.skew().sort_values()
# Out:
# pcircle                  0.000000
# pdate                    0.116409
# maxamnt_loans90          1.678304
# fr_ma_rech90             2.285423
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# amnt_loans90             3.150006
# cnt_ma_rech30            3.283842
# cnt_ma_rech90            3.425254
# medianamnt_ma_rech30     3.512324
# medianamnt_ma_rech90     3.752706
# last_rech_amt_ma         3.781149
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental90                 4.437681
# rental30                 4.521929
# medianamnt_loans30       4.551043
# medianamnt_loans90       4.895720
# sumamnt_ma_rech90        4.897950
# sumamnt_ma_rech30        6.386787
# payback90                6.899951
# payback30                8.310695
# medianmarechprebal90    44.880503
# dtype: float64

# %%
num_columns
# Out:
# ['label',
#  'daily_decr30',
#  'daily_decr90',
#  'rental30',
#  'rental90',
#  'last_rech_amt_ma',
#  'cnt_ma_rech30',
#  'sumamnt_ma_rech30',
#  'medianamnt_ma_rech30',
#  'cnt_ma_rech90',
#  'fr_ma_rech90',
#  'sumamnt_ma_rech90',
#  'medianamnt_ma_rech90',
#  'medianmarechprebal90',
#  'cnt_loans30',
#  'amnt_loans30',
#  'medianamnt_loans30',
#  'amnt_loans90',
#  'maxamnt_loans90',
#  'medianamnt_loans90',
#  'payback30',
#  'payback90']

# %%
#removing skewness
import numpy as np
for i in num_columns:
    x1[i]=np.sqrt(x1[i])
    
#Code does not work as invalid values comes

# %% [markdown]
# -skewness is increased at a certain level so we will try some other method

# %%
x1=x.copy()

#Transforming the data for skewness
from sklearn.preprocessing import power_transform

x1=power_transform(x1)

x1=pd.DataFrame(data=x1,columns=x.columns)
x1.skew().sort_values()
# Out:
# daily_decr90           -7.080193
# daily_decr30           -6.582717
# rental30               -1.022844
# rental90               -0.962717
# sumamnt_ma_rech30      -0.291322
# pdate                  -0.217699
# sumamnt_ma_rech90      -0.192158
# medianamnt_ma_rech30   -0.189628
# last_rech_amt_ma       -0.061262
# medianamnt_ma_rech90   -0.044604
# amnt_loans90           -0.008988
# cnt_ma_rech90          -0.002465
# cnt_ma_rech30          -0.000145
# pcircle                 0.000000
# amnt_loans30            0.001948
# cnt_loans30             0.036243
# fr_ma_rech90            0.142952
# payback90               0.210887
# payback30               0.298563
# maxamnt_loans90         0.364282
# medianamnt_loans30      3.447735
# medianamnt_loans90      3.779598
# medianmarechprebal90    7.506286
# dtype: float64

# %%
x2=x.copy()
#lets try some other method
#removing skewness
import numpy as np
for i in num_columns:
    x2[i]=np.log(x2[i])

x2

#This code also does not work due to invalid values

# %%
x1.skew().sort_values()
# Out:
# daily_decr90           -7.080193
# daily_decr30           -6.582717
# rental30               -1.022844
# rental90               -0.962717
# sumamnt_ma_rech30      -0.291322
# pdate                  -0.217699
# sumamnt_ma_rech90      -0.192158
# medianamnt_ma_rech30   -0.189628
# last_rech_amt_ma       -0.061262
# medianamnt_ma_rech90   -0.044604
# amnt_loans90           -0.008988
# cnt_ma_rech90          -0.002465
# cnt_ma_rech30          -0.000145
# pcircle                 0.000000
# amnt_loans30            0.001948
# cnt_loans30             0.036243
# fr_ma_rech90            0.142952
# payback90               0.210887
# payback30               0.298563
# maxamnt_loans90         0.364282
# medianamnt_loans30      3.447735
# medianamnt_loans90      3.779598
# medianmarechprebal90    7.506286
# dtype: float64

# %% [markdown]
# - Skewness is at acceptable level in second method of power_transform so we will use x1 data frame

# %%
#After removing skewness of x1 , it is used as x
x=x1

# %% [markdown]
# Skeyness is at acceptable level now we can use this data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Scaling the data, since outlier are not present and features are on different scale so we will use MinMaxScaler
x3=x.copy()
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
x3 = scale.fit_transform(x3)
x3
# Out:
# array([[0.96613754, 0.96666734, 0.72989195, ..., 0.85506865, 0.        ,
#         0.69905478],
#        [0.97296793, 0.9730118 , 0.73831946, ..., 0.        , 0.        ,
#         0.90168993],
#        [0.9631778 , 0.9638827 , 0.73184951, ..., 0.        , 0.        ,
#         0.98245471],
#        ...,
#        [0.97283229, 0.97291262, 0.74276579, ..., 0.54053628, 0.        ,
#         0.78869307],
#        [0.97314251, 0.97320996, 0.73048867, ..., 0.71896775, 0.        ,
#         0.74943541],
#        [0.96781812, 0.96826621, 0.73070083, ..., 0.        , 0.        ,
#         0.559766  ]])

# %%
x=pd.DataFrame(x3,columns=x1.columns)
x
# Out:
#         daily_decr30  daily_decr90  rental30  rental90  last_rech_amt_ma  \
# 0           0.966138      0.966667  0.729892  0.772163          0.267205
# 1           0.972968      0.973012  0.738319  0.779368          0.439478
# 2           0.963178      0.963883  0.731850  0.773766          0.267205
# 3           0.954255      0.955423  0.729688  0.771868          0.221707
# 4           0.957298      0.958331  0.732367  0.774216          0.311691
# ...              ...           ...       ...       ...               ...
# 209588      0.957314      0.958346  0.732342  0.774195          0.384791
# 209589      0.954963      0.956103  0.733921  0.775568          0.204884
# 209590      0.972832      0.972913  0.742766  0.788160          0.267205
# 209591      0.973143      0.973210  0.730489  0.773959          0.204884
# 209592      0.967818      0.968266  0.730701  0.773128          0.484327
#
#         cnt_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  cnt_ma_rech90  \
# 0            0.206106           0.171847              0.262157       0.181799
# 1            0.130010           0.211484              0.434141       0.114335
# 2            0.130010           0.136222              0.262157       0.114335
# 3            0.000000           0.000000              0.000000       0.114335
# 4            0.390323           0.315417              0.306436       0.366777
# ...               ...                ...                   ...            ...
# 209588       0.260118           0.255753              0.346142       0.229928
# 209589       0.302024           0.172105              0.200323       0.324179
# 209590       0.336271           0.246960              0.262157       0.415748
# 209591       0.336271           0.268864              0.200323       0.324179
# 209592       0.206106           0.244639              0.395965       0.229928
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0           0.802911           0.173456              0.254662
# 1           0.000000           0.212161              0.426152
# 2           0.000000           0.138403              0.254662
# 3           0.000000           0.117740              0.210006
# 4           0.361939           0.328273              0.325818
# ...              ...                ...                   ...
# 209588      0.361939           0.255089              0.338154
# 209589      0.361939           0.189231              0.193580
# 209590      0.542065           0.305438              0.254662
# 209591      0.497815           0.302095              0.303671
# 209592      0.786652           0.294880              0.471293
#
#         medianmarechprebal90  cnt_loans30  amnt_loans30  medianamnt_loans30  \
# 0                   0.125380     0.506193      0.441865                 0.0
# 1                   0.130336     0.352901      0.441865                 0.0
# 2                   0.130743     0.352901      0.334339                 0.0
# 3                   0.124688     0.506193      0.441865                 0.0
# 4                   0.128185     0.764556      0.651263                 0.0
# ...                      ...          ...           ...                 ...
# 209588              0.132607     0.506193      0.441865                 0.0
# 209589              0.133982     0.596460      0.508062                 0.0
# 209590              0.129222     0.657511      0.651263                 0.0
# 209591              0.133179     0.506193      0.508062                 0.0
# 209592              0.149743     0.506193      0.508062                 0.0
#
#         amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 0           0.486415         0.643145                 0.0   0.899398
# 1           0.486415         1.000000                 0.0   0.000000
# 2           0.378730         0.643145                 0.0   0.000000
# 3           0.486415         0.643145                 0.0   0.000000
# 4           0.678819         0.643145                 0.0   0.515521
# ...              ...              ...                 ...        ...
# 209588      0.486415         0.643145                 0.0   0.337569
# 209589      0.549627         0.643145                 0.0   0.337569
# 209590      0.715990         1.000000                 0.0   0.625075
# 209591      0.594061         1.000000                 0.0   0.000000
# 209592      0.549627         1.000000                 0.0   0.000000
#
#         payback90  pcircle     pdate
# 0        0.855069      0.0  0.699055
# 1        0.000000      0.0  0.901690
# 2        0.000000      0.0  0.982455
# 3        0.000000      0.0  0.125015
# 4        0.442457      0.0  0.377284
# ...           ...      ...       ...
# 209588   0.280849      0.0  0.308108
# 209589   0.280849      0.0  0.231999
# 209590   0.540536      0.0  0.788693
# 209591   0.718968      0.0  0.749435
# 209592   0.000000      0.0  0.559766
#
# [209593 rows x 23 columns]

# %% [markdown]
# ### Balancing Class

# %%
#checking for null values
x.isna().sum()
# Out:
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_loans30             0
# amnt_loans30            0
# medianamnt_loans30      0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# dtype: int64

# %%
#balancing the class in target feature
#Since data has huge number of rows hence rather than
#oversampling we will do undersampling to avoid wastage of time amnd complexity to the model

from imblearn.under_sampling import RandomUnderSampler
rus=RandomUnderSampler(random_state=40,replacement=True)
x,y=rus.fit_resample(x,y)

# %%
x=pd.DataFrame(x)
x
# Out:
#        daily_decr30  daily_decr90  rental30  rental90  last_rech_amt_ma  \
# 0          0.966138      0.966667  0.729892  0.772163          0.267205
# 1          0.955806      0.956910  0.730229  0.772346          0.484327
# 2          0.953632      0.954824  0.732667  0.774477          0.000000
# 3          0.962074      0.962845  0.732113  0.774192          0.000000
# 4          0.960138      0.961024  0.729308  0.771537          0.204884
# ...             ...           ...       ...       ...               ...
# 52319      0.958365      0.959345  0.725028  0.767401          0.384791
# 52320      0.959151      0.960089  0.740869  0.782706          0.204573
# 52321      0.964647      0.965261  0.731133  0.773139          0.204573
# 52322      0.954983      0.956122  0.740367  0.781129          0.267205
# 52323      0.969642      0.969974  0.731257  0.773810          0.204573
#
#        cnt_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  cnt_ma_rech90  \
# 0           0.206106           0.171847              0.262157       0.181799
# 1           0.206106           0.244639              0.395965       0.181799
# 2           0.000000           0.000000              0.000000       0.000000
# 3           0.000000           0.000000              0.000000       0.000000
# 4           0.130010           0.107513              0.200323       0.181799
# ...              ...                ...                   ...            ...
# 52319       0.336271           0.366310              0.490188       0.346792
# 52320       0.130010           0.107368              0.200015       0.114335
# 52321       0.206106           0.136252              0.200015       0.229928
# 52322       0.260118           0.185055              0.262157       0.229928
# 52323       0.390323           0.224324              0.200015       0.384686
#
#        fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 0          0.802911           0.173456              0.254662
# 1          0.000000           0.244338              0.387919
# 2          0.000000           0.000000              0.000000
# 3          0.000000           0.000000              0.000000
# 4          0.961762           0.138610              0.193580
# ...             ...                ...                   ...
# 52319      0.542065           0.398170              0.482427
# 52320      0.000000           0.109786              0.193277
# 52321      0.957784           0.158144              0.193277
# 52322      0.361939           0.186385              0.254662
# 52323      0.000000           0.298426              0.193277
#
#        medianmarechprebal90  cnt_loans30  amnt_loans30  medianamnt_loans30  \
# 0                  0.125380     0.506193      0.441865                 0.0
# 1                  0.154416     0.352901      0.334339                 0.0
# 2                  0.124245     0.352901      0.334339                 0.0
# 3                  0.124245     0.352901      0.334339                 0.0
# 4                  0.144143     0.506193      0.441865                 0.0
# ...                     ...          ...           ...                 ...
# 52319              0.131144     0.506193      0.441865                 0.0
# 52320              0.125779     0.352901      0.334339                 0.0
# 52321              0.125917     0.506193      0.441865                 0.0
# 52322              0.125029     0.657511      0.556068                 0.0
# 52323              0.167065     0.352901      0.334339                 0.0
#
#        amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 0          0.486415         0.643145                 0.0   0.899398
# 1          0.378730         0.643145                 0.0   0.000000
# 2          0.378730         0.643145                 0.0   0.000000
# 3          0.378730         0.643145                 0.0   0.000000
# 4          0.486415         0.643145                 0.0   0.000000
# ...             ...              ...                 ...        ...
# 52319      0.486415         0.643145                 0.0   0.337569
# 52320      0.378730         0.643145                 0.0   0.000000
# 52321      0.549627         0.643145                 0.0   0.839575
# 52322      0.594061         0.643145                 0.0   0.739446
# 52323      0.378730         0.643145                 0.0   0.000000
#
#        payback90  pcircle     pdate
# 0       0.855069      0.0  0.699055
# 1       0.000000      0.0  0.350287
# 2       0.000000      0.0  0.403508
# 3       0.000000      0.0  0.525519
# 4       0.000000      0.0  0.490292
# ...          ...      ...       ...
# 52319   0.280849      0.0  0.377284
# 52320   0.000000      0.0  0.688789
# 52321   0.780942      0.0  0.827110
# 52322   0.667528      0.0  0.403508
# 52323   0.000000      0.0  0.668055
#
# [52324 rows x 23 columns]

# %%
#showing the counts of target classes are not balanced
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# - classes are balanced

# %% [markdown]
# ##### Checking the best random state for splitting the the data in train and test

# %%
#importing necessary libraries
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import r2_score,mean_squared_error, mean_absolute_error #For checking loss function (errors)

from sklearn.model_selection import cross_val_score

from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

#Checking the best random state
tr_acc=0
tr_i=0

for i in range(0,25):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
 
    if(round(accuracy_score(y_test,pred_test)*100)>tr_acc):
        tr_acc=accuracy_score(y_test,pred_test)*100
        tr_i=i

print(" Best Test Accuracy ",tr_acc," at ",tr_i)
# Out:
#  Best Test Accuracy  76.94218824653606  at  17

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=17)

# %%
#checking the shape of x_train
x_train.shape
# Out:
# (41859, 23)

# %%
#checking the shape of y_train
y_train.shape
# Out:
# (41859,)

# %%
#checking the shape of x_test
x_test.shape
# Out:
# (10465, 23)

# %%
#checking the shape of y_test
y_test.shape
# Out:
# (10465,)

# %% [markdown]
# # Fitting the models

# %% [markdown]
# ### LogisticRegression

# %%
print("Accuracy Score is ",accuracy_score(y_test,pred_test))
print(confusion_matrix(y_test,pred_test))
print(classification_report(y_test,pred_test))

from sklearn.model_selection import cross_val_score
src=cross_val_score(lr,x,y,cv=7)
print("Cross_val_score ",src,"\n\n  mean ",src.mean())
# Out:
# Accuracy Score is  0.4973721930243669
# [[2663 2626]
#  [2634 2542]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50      5289
#            1       0.49      0.49      0.49      5176
#
#     accuracy                           0.50     10465
#    macro avg       0.50      0.50      0.50     10465
# weighted avg       0.50      0.50      0.50     10465
#
# Cross_val_score  [0.75665552 0.75331104 0.7606689  0.75719064 0.75812709 0.75638796
#  0.7592989 ]
#
#   mean  0.7573771485695721

# %% [markdown]
# - Accuracy score is not good

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
svc=SVC()

svc.fit(x_train,y_train)
pred_test=svc.predict(x_test)
 

print("Accuracy Score is ",accuracy_score(y_test,pred_test))
print(confusion_matrix(y_test,pred_test))
print(classification_report(y_test,pred_test))
# Out:
# Accuracy Score is  0.8069756330625896
# [[4343  946]
#  [1074 4102]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81      5289
#            1       0.81      0.79      0.80      5176
#
#     accuracy                           0.81     10465
#    macro avg       0.81      0.81      0.81     10465
# weighted avg       0.81      0.81      0.81     10465

# %% [markdown]
# Accuracy Score is 80% in SVC which is good

# %% [markdown]
# ##### Checking Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score
src=cross_val_score(svc,x,y,cv=7)
print("Cross_val_score ",src,"\n\n  mean ",src.mean())
# Out:
# Cross_val_score  [0.79785953 0.79491639 0.7993311  0.79732441 0.79464883 0.80267559
#  0.80465614]
#
#   mean  0.7987731420189448

# %% [markdown]
# - SVC accuracy is 80 and CV Score is 78 not a good performer

# %% [markdown]
# ## DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
pred_test=dtc.predict(x_test)
print("Accuracy Score is ",accuracy_score(y_test,pred_test))
print(confusion_matrix(y_test,pred_test))
print(classification_report(y_test,pred_test))

from sklearn.model_selection import cross_val_score
src=cross_val_score(dtc,x,y,cv=7)
print("Cross_val_score ",src,"\n\n  mean ",src.mean())
# Out:
# Accuracy Score is  0.8139512661251792
# [[4276 1013]
#  [ 934 4242]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81      5289
#            1       0.81      0.82      0.81      5176
#
#     accuracy                           0.81     10465
#    macro avg       0.81      0.81      0.81     10465
# weighted avg       0.81      0.81      0.81     10465
#
# Cross_val_score  [0.81190635 0.80829431 0.81003344 0.81070234 0.80508361 0.81257525
#  0.81067701]
#
#   mean  0.8098960473390091

# %% [markdown]
# ##### The accuracy of the model is 81% and cv score is 81 which is  good

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=300)
rfc.fit(x_train,y_train)
pred_test=rfc.predict(x_test)
print("Accuracy Score is ",accuracy_score(y_test,pred_test))
print(confusion_matrix(y_test,pred_test))
print(classification_report(y_test,pred_test))

#Checking Cross Validation Score

from sklearn.model_selection import cross_val_score
src=cross_val_score(rfc,x,y,cv=7)
print("Cross_val_score",src,"\n\n  mean ",src.mean())
# Out:
# Accuracy Score is  0.861729574773053
# [[4526  763]
#  [ 684 4492]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      5289
#            1       0.85      0.87      0.86      5176
#
#     accuracy                           0.86     10465
#    macro avg       0.86      0.86      0.86     10465
# weighted avg       0.86      0.86      0.86     10465
#
# Cross_val_score [0.85939799 0.85565217 0.85886288 0.85886288 0.85591973 0.86287625
#  0.86473107]
#
#   mean  0.8594718534365543

# %% [markdown]
# The accuracy of the model is 86% and cv score is 86 which is also  good

# %% [markdown]
# ## KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knc=KNeighborsClassifier()
knc.fit(x_train,y_train)
pred_test=knc.predict(x_test)
print("Accuracy Score is ",accuracy_score(y_test,pred_test))
print(confusion_matrix(y_test,pred_test))
print(classification_report(y_test,pred_test))

#Checking Cross Validation Score

src=cross_val_score(knc,x,y,cv=7)
print("Cross_val_score ",src,"\n\n  mean ",src.mean())
# Out:
# Accuracy Score is  0.8093645484949833
# [[4319  970]
#  [1025 4151]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81      5289
#            1       0.81      0.80      0.81      5176
#
#     accuracy                           0.81     10465
#    macro avg       0.81      0.81      0.81     10465
# weighted avg       0.81      0.81      0.81     10465
#
# Cross_val_score  [0.80240803 0.80053512 0.80080268 0.79906355 0.80187291 0.8032107
#  0.80840246]
#
#   mean  0.8023279197794909

# %% [markdown]
# - Accuracy score is 80% CV score = 80

# %% [markdown]
# ### Best model is RandomForestClassifier with 86% accuracy score

# %%
#checking best cv value
rfc.fit(x_train,y_train)
pred_test=rfc.predict(x_test)
test_accuracy=accuracy_score(y_test,pred_test)

bestcv=0
bestj=0

from sklearn.model_selection import cross_val_score
for j in range(3,5):
    cv_score=cross_val_score(dtc,x,y,cv=j)
    cv_mean=cv_score.mean()
    if(cv_mean*100>bestcv):
        bestcv=cv_mean*100
        bestj=j

print(f"At cross fold {bestj} the best cv score is {bestcv} and testing accuracy is {test_accuracy}")
print("\n")
# Out:
# At cross fold 4 the best cv score is 80.55194556991056 and testing accuracy is 0.8615384615384616

# %% [markdown]
# - CV 4 is best

# %% [markdown]
# ## Hyper Parameter Tuning

# %% [markdown]
# #### Parameter fine tuning

# %%
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# %%
parameters={'n_estimators':[200,400],'max_depth':[1,2,3,4]}
   

clf = GridSearchCV(rfc,parameters,cv=39)
clf.fit(x_train,y_train)

print(clf.best_params_)

#to save time less parameters are used still it takes long time

# %%
#final model training 
rfc=RandomForestClassifier(n_estimators=300, max_depth=4)

rfc.fit(x_train,y_train)
pred=rfc.predict(x_test)
print("Accuracy Score is ",accuracy_score(y_test,pred))


#Checking Cross Validation Score

from sklearn.model_selection import cross_val_score
src=cross_val_score(rfc,x,y,cv=7)
print("Cross_val_score",src,"\n\n  mean ",src.mean())
# Out:
# Accuracy Score is  0.862876254180602
# Cross_val_score [0.85765886 0.8548495  0.85939799 0.85913043 0.85578595 0.86434783
#  0.8633931 ]
#
#   mean  0.8592233806611765

# %% [markdown]
# - Accuracy score is 86% which is good

# %% [markdown]
# ## Conclusion : Saving the best Model

# %%
#saving the model
import pickle
outfile=open('a1.pkl','wb')
pickle.dump(rfc,outfile)
outfile.close()

# %% [markdown]
# ## Conclusion : Retrieving the best Model

# %%
#loading the model
infile=open('a1.pkl','rb')
new_rf=pickle.load(infile)
infile.close()

result = new_rf.score(x_test,y_test)
result*100
# Out:
# 86.2876254180602

# %%
pred_decision=y_test
conclusion=pd.DataFrame([new_rf.predict(x_test)[:],pred_decision[:]],index=["Predicted","Original"])
conclusion
# Out:
#            0      1      2      3      4      5      6      7      8      \
# Predicted      0      0      0      0      0      0      1      0      1
# Original       0      0      0      0      0      0      0      0      1
#
#            9      10     11     12     13     14     15     16     17     ...  \
# Predicted      1      0      0      1      1      1      0      1      1  ...
# Original       1      0      0      1      1      1      0      1      0  ...
#
#            10447  10448  10449  10450  10451  10452  10453  10454  10455  \
# Predicted      0      1      1      1      0      0      1      0      1
# Original       0      1      1      1      0      0      1      0      1
#
#            10456  10457  10458  10459  10460  10461  10462  10463  10464
# Predicted      1      0      1      0      1      1      0      0      0
# Original       1      0      1      0      1      1      0      0      0
#
# [2 rows x 10465 columns]

# %% [markdown]
# ##### End of Analysis
